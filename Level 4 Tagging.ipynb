# %% [markdown]
# ### Tagging

# %% [markdown]
# So here is Mr. James Wilson who wrote about Elon Musk. Here is the following content.
#
# ~~~~
# Musk was born on June 28, 1971, in Pretoria, Gauteng, South Africa,[27] the son of Maye Musk (née Haldeman), a model and dietician from Regina, Saskatchewan, Canada;[28] and Errol Musk, a South African electromechanical engineer, pilot and sailor. He has a younger brother, Kimbal (born 1972), and a younger sister, Tosca (born 1974).[28][29][30][31] His paternal grandmother was British, and he also has Pennsylvania Dutch ancestry,[32][33] and his maternal grandfather was American, from Minnesota.[34] After his parents divorced in 1980, Musk lived mostly with his father in the suburbs of Pretoria.[32]
#
# During his childhood he had an interest in reading and often did so for hours at a time.[35]
#
# At What age did Musk got interested in computing? At age 10, he developed an interest in computing with the Commodore VIC-20.[36] He taught himself computer programming at the age of 12, sold the code for a BASIC-based video game he created called Blastar, to a magazine called PC and Office Technology, for approximately $500. [37][38] A web version of the game is available online.[37][39]
#
# Musk was severely bullied throughout his childhood, and was once hospitalized when a group of boys threw him down a flight of stairs and then beat him until he lost consciousness.[40]
#
# Musk was initially educated at private schools, attending the English-speaking Waterkloof House Preparatory School.
#
# Mr. Singh helped Musk during his initial days when he was severely bullied during his childhood.
#
# Musk later graduated from Pretoria Boys High School and moved to Canada in June 1989, just before his 18th birthday,[41] after obtaining Canadian citizenship through his Canadian-born mother.[42][43] Although at the time Musk had to register to become a Canadian citizen, Bill C-37, which came into law in April of 2009, effectively made his Canadian citizenship retroactive to his birth since he was born in the first generation abroad to a Canadian-born mother. Therefore, with the law change, he is considered to have always been a Canadian citizen by birth.
# ~~~~

# %% [markdown]
# ### Part - 1
#
# 1. Tag the given content using POS Tagger
#
# 2. Default Tag the entire content with the tag which appears most number of times
#
# ### Part - 2
#
# Create your own Tagger using the following rules
#
# Let's try to understand some **Parts Of Speech**
#
# 1. **Possesion Noun (NN\$)** - any word which ends with **'s**
#     > ***Jennifer’s*** new handbag matches her shoes perfectly
# 2. **Gerund (VBG)** - any word which ends with **ing**
#     > ***Swimming*** in the ocean has been Sharon’s passion since she was five years old.
# 3. **Simple Past (VBD)** - any word which ends with **ed**
#     > We ***crossed*** the Channel yesterday.
# 4. **Modal (MD)** - any word which ends with **ould**
#     > He **should** not be late
# 5. **Third Singular Present (VBZ)** - any word which ends with **es**
#     > He **misses** her so much
# 6. **Numbers (CD)** - any number integer or decimal
#     > 24.90
# 7. **Plural Nouns (NNS)** - any word ending with **s**
#     > You stole my **ideas** and didn’t give me any credit.

# %% [markdown]
# ## Part1

# %%
from nltk.tokenize import RegexpTokenizer, sent_tokenize, PunktSentenceTokenizer, word_tokenize
import nltk

# %%
sample_data = """Musk was born on June 28, 1971, in Pretoria, Gauteng, South Africa,[27] the son of Maye Musk (née Haldeman), a model and dietician from Regina, Saskatchewan, Canada;[28] and Errol Musk, a South African electromechanical engineer, pilot and sailor. He has a younger brother, Kimbal (born 1972), and a younger sister, Tosca (born 1974).[28][29][30][31] His paternal grandmother was British, and he also has Pennsylvania Dutch ancestry,[32][33] and his maternal grandfather was American, from Minnesota.[34] After his parents divorced in 1980, Musk lived mostly with his father in the suburbs of Pretoria.[32]

During his childhood he had an interest in reading and often did so for hours at a time.[35]

At What age did Musk got interested in computing? At age 10, he developed an interest in computing with the Commodore VIC-20.[36] He taught himself computer programming at the age of 12, sold the code for a BASIC-based video game he created called Blastar, to a magazine called PC and Office Technology, for approximately $500. [37][38] A web version of the game is available online.[37][39]

Musk was severely bullied throughout his childhood, and was once hospitalized when a group of boys threw him down a flight of stairs and then beat him until he lost consciousness.[40]

Musk was initially educated at private schools, attending the English-speaking Waterkloof House Preparatory School. 

Mr. Singh helped Musk during his initial days when he was severely bullied during his childhood.

Musk later graduated from Pretoria Boys High School and moved to Canada in June 1989, just before his 18th birthday,[41] after obtaining Canadian citizenship through his Canadian-born mother.[42][43] Although at the time Musk had to register to become a Canadian citizen, Bill C-37, which came into law in April of 2009, effectively made his Canadian citizenship retroactive to his birth since he was born in the first generation abroad to a Canadian-born mother. Therefore, with the law change, he is considered to have always been a Canadian citizen by birth."""

# %%
pattern = RegexpTokenizer(r'\w+')

# %%
sentences = sent_tokenize(sample_data)

# %%
c=0
tags = []
for line in sentences:
    word = pattern.tokenize(line)
    tagged = nltk.pos_tag(word)
    c = c + len(tagged)
    for words,pos in tagged:
        tags.append(pos)
        
    print(tagged)
print(c)
# Out:
# [('Musk', 'NNP'), ('was', 'VBD'), ('born', 'VBN'), ('on', 'IN'), ('June', 'NNP'), ('28', 'CD'), ('1971', 'CD'), ('in', 'IN'), ('Pretoria', 'NNP'), ('Gauteng', 'NNP'), ('South', 'NNP'), ('Africa', 'NNP'), ('27', 'CD'), ('the', 'DT'), ('son', 'NN'), ('of', 'IN'), ('Maye', 'NNP'), ('Musk', 'NNP'), ('née', 'MD'), ('Haldeman', 'NNP'), ('a', 'DT'), ('model', 'NN'), ('and', 'CC'), ('dietician', 'JJ'), ('from', 'IN'), ('Regina', 'NNP'), ('Saskatchewan', 'NNP'), ('Canada', 'NNP'), ('28', 'CD'), ('and', 'CC'), ('Errol', 'NNP'), ('Musk', 'NNP'), ('a', 'DT'), ('South', 'JJ'), ('African', 'JJ'), ('electromechanical', 'JJ'), ('engineer', 'NN'), ('pilot', 'NN'), ('and', 'CC'), ('sailor', 'NN')]
# [('He', 'PRP'), ('has', 'VBZ'), ('a', 'DT'), ('younger', 'JJR'), ('brother', 'NN'), ('Kimbal', 'NNP'), ('born', 'NN'), ('1972', 'CD'), ('and', 'CC'), ('a', 'DT'), ('younger', 'JJR'), ('sister', 'NN'), ('Tosca', 'NNP'), ('born', 'NN'), ('1974', 'CD')]
# [('28', 'CD'), ('29', 'CD'), ('30', 'CD'), ('31', 'CD'), ('His', 'PRP$'), ('paternal', 'JJ'), ('grandmother', 'NN'), ('was', 'VBD'), ('British', 'JJ'), ('and', 'CC'), ('he', 'PRP'), ('also', 'RB'), ('has', 'VBZ'), ('Pennsylvania', 'NNP'), ('Dutch', 'NNP'), ('ancestry', 'NN'), ('32', 'CD'), ('33', 'CD'), ('and', 'CC'), ('his', 'PRP$'), ('maternal', 'JJ'), ('grandfather', 'NN'), ('was', 'VBD'), ('American', 'JJ'), ('from', 'IN'), ('Minnesota', 'NNP')]
# [('34', 'CD'), ('After', 'IN'), ('his', 'PRP$'), ('parents', 'NNS'), ('divorced', 'VBN'), ('in', 'IN'), ('1980', 'CD'), ('Musk', 'NNP'), ('lived', 'VBD'), ('mostly', 'RB'), ('with', 'IN'), ('his', 'PRP$'), ('father', 'NN'), ('in', 'IN'), ('the', 'DT'), ('suburbs', 'NN'), ('of', 'IN'), ('Pretoria', 'NNP')]
# [('32', 'CD'), ('During', 'IN'), ('his', 'PRP$'), ('childhood', 'NN'), ('he', 'PRP'), ('had', 'VBD'), ('an', 'DT'), ('interest', 'NN'), ('in', 'IN'), ('reading', 'NN'), ('and', 'CC'), ('often', 'RB'), ('did', 'VBD'), ('so', 'RB'), ('for', 'IN'), ('hours', 'NNS'), ('at', 'IN'), ('a', 'DT'), ('time', 'NN')]
# [('35', 'CD'), ('At', 'IN'), ('What', 'WP'), ('age', 'NN'), ('did', 'VBD'), ('Musk', 'NNP'), ('got', 'VBD'), ('interested', 'JJ'), ('in', 'IN'), ('computing', 'VBG')]
# [('At', 'IN'), ('age', 'NN'), ('10', 'CD'), ('he', 'PRP'), ('developed', 'VBD'), ('an', 'DT'), ('interest', 'NN'), ('in', 'IN'), ('computing', 'VBG'), ('with', 'IN'), ('the', 'DT'), ('Commodore', 'NNP'), ('VIC', 'NNP'), ('20', 'CD')]
# [('36', 'CD'), ('He', 'PRP'), ('taught', 'VBD'), ('himself', 'PRP'), ('computer', 'NN'), ('programming', 'VBG'), ('at', 'IN'), ('the', 'DT'), ('age', 'NN'), ('of', 'IN'), ('12', 'CD'), ('sold', 'VBD'), ('the', 'DT'), ('code', 'NN'), ('for', 'IN'), ('a', 'DT'), ('BASIC', 'NNP'), ('based', 'VBN'), ('video', 'NN'), ('game', 'NN'), ('he', 'PRP'), ('created', 'VBD'), ('called', 'VBN'), ('Blastar', 'NNP'), ('to', 'TO'), ('a', 'DT'), ('magazine', 'NN'), ('called', 'VBN'), ('PC', 'NN'), ('and', 'CC'), ('Office', 'NNP'), ('Technology', 'NNP'), ('for', 'IN'), ('approximately', 'RB'), ('500', 'CD')]
# [('37', 'CD'), ('38', 'CD'), ('A', 'NNP'), ('web', 'JJ'), ('version', 'NN'), ('of', 'IN'), ('the', 'DT'), ('game', 'NN'), ('is', 'VBZ'), ('available', 'JJ'), ('online', 'NN')]
# [('37', 'CD'), ('39', 'CD'), ('Musk', 'NNP'), ('was', 'VBD'), ('severely', 'RB'), ('bullied', 'VBN'), ('throughout', 'IN'), ('his', 'PRP$'), ('childhood', 'NN'), ('and', 'CC'), ('was', 'VBD'), ('once', 'RB'), ('hospitalized', 'VBN'), ('when', 'WRB'), ('a', 'DT'), ('group', 'NN'), ('of', 'IN'), ('boys', 'NNS'), ('threw', 'VBD'), ('him', 'PRP'), ('down', 'RP'), ('a', 'DT'), ('flight', 'NN'), ('of', 'IN'), ('stairs', 'NNS'), ('and', 'CC'), ('then', 'RB'), ('beat', 'VBD'), ('him', 'PRP'), ('until', 'IN'), ('he', 'PRP'), ('lost', 'VBD'), ('consciousness', 'NN')]
# [('40', 'CD'), ('Musk', 'NNP'), ('was', 'VBD'), ('initially', 'RB'), ('educated', 'VBN'), ('at', 'IN'), ('private', 'JJ'), ('schools', 'NNS'), ('attending', 'VBG'), ('the', 'DT'), ('English', 'JJ'), ('speaking', 'NN'), ('Waterkloof', 'NNP'), ('House', 'NNP'), ('Preparatory', 'NNP'), ('School', 'NNP')]
# [('Mr', 'NNP'), ('Singh', 'NNP'), ('helped', 'VBD'), ('Musk', 'NNP'), ('during', 'IN'), ('his', 'PRP$'), ('initial', 'JJ'), ('days', 'NNS'), ('when', 'WRB'), ('he', 'PRP'), ('was', 'VBD'), ('severely', 'RB'), ('bullied', 'VBN'), ('during', 'IN'), ('his', 'PRP$'), ('childhood', 'NN')]
# [('Musk', 'NNP'), ('later', 'RB'), ('graduated', 'VBD'), ('from', 'IN'), ('Pretoria', 'NNP'), ('Boys', 'NNP'), ('High', 'NNP'), ('School', 'NNP'), ('and', 'CC'), ('moved', 'VBD'), ('to', 'TO'), ('Canada', 'NNP'), ('in', 'IN'), ('June', 'NNP'), ('1989', 'CD'), ('just', 'RB'), ('before', 'IN'), ('his', 'PRP$'), ('18th', 'CD'), ('birthday', 'NN'), ('41', 'CD'), ('after', 'IN'), ('obtaining', 'VBG'), ('Canadian', 'JJ'), ('citizenship', 'NN'), ('through', 'IN'), ('his', 'PRP$'), ('Canadian', 'JJ'), ('born', 'NN'), ('mother', 'NN')]
# [('42', 'CD'), ('43', 'CD'), ('Although', 'IN'), ('at', 'IN'), ('the', 'DT'), ('time', 'NN'), ('Musk', 'NNP'), ('had', 'VBD'), ('to', 'TO'), ('register', 'VB'), ('to', 'TO'), ('become', 'VB'), ('a', 'DT'), ('Canadian', 'JJ'), ('citizen', 'NN'), ('Bill', 'NNP'), ('C', 'NNP'), ('37', 'CD'), ('which', 'WDT'), ('came', 'VBD'), ('into', 'IN'), ('law', 'NN'), ('in', 'IN'), ('April', 'NNP'), ('of', 'IN'), ('2009', 'CD'), ('effectively', 'RB'), ('made', 'VBD'), ('his', 'PRP$'), ('Canadian', 'JJ'), ('citizenship', 'NN'), ('retroactive', 'JJ'), ('to', 'TO'), ('his', 'PRP$'), ('birth', 'NN'), ('since', 'IN'), ('he', 'PRP'), ('was', 'VBD'), ('born', 'VBN'), ('in', 'IN'), ('the', 'DT'), ('first', 'JJ'), ('generation', 'NN'), ('abroad', 'RB'), ('to', 'TO'), ('a', 'DT'), ('Canadian', 'JJ'), ('born', 'NN'), ('mother', 'NN')]
# [('Therefore', 'RB'), ('with', 'IN'), ('the', 'DT'), ('law', 'NN'), ('change', 'NN'), ('he', 'PRP'), ('is', 'VBZ'), ('considered', 'VBN'), ('to', 'TO'), ('have', 'VB'), ('always', 'RB'), ('been', 'VBN'), ('a', 'DT'), ('Canadian', 'JJ'), ('citizen', 'NN'), ('by', 'IN'), ('birth', 'NN')]
# 349

# %%
tagged = nltk.pos_tag(pattern.tokenize(sample_data))

# %%
print(tagged)
# Out:
# [('Musk', 'NNP'), ('was', 'VBD'), ('born', 'VBN'), ('on', 'IN'), ('June', 'NNP'), ('28', 'CD'), ('1971', 'CD'), ('in', 'IN'), ('Pretoria', 'NNP'), ('Gauteng', 'NNP'), ('South', 'NNP'), ('Africa', 'NNP'), ('27', 'CD'), ('the', 'DT'), ('son', 'NN'), ('of', 'IN'), ('Maye', 'NNP'), ('Musk', 'NNP'), ('née', 'MD'), ('Haldeman', 'NNP'), ('a', 'DT'), ('model', 'NN'), ('and', 'CC'), ('dietician', 'JJ'), ('from', 'IN'), ('Regina', 'NNP'), ('Saskatchewan', 'NNP'), ('Canada', 'NNP'), ('28', 'CD'), ('and', 'CC'), ('Errol', 'NNP'), ('Musk', 'NNP'), ('a', 'DT'), ('South', 'JJ'), ('African', 'JJ'), ('electromechanical', 'JJ'), ('engineer', 'NN'), ('pilot', 'NN'), ('and', 'CC'), ('sailor', 'NN'), ('He', 'PRP'), ('has', 'VBZ'), ('a', 'DT'), ('younger', 'JJR'), ('brother', 'NN'), ('Kimbal', 'NNP'), ('born', 'NN'), ('1972', 'CD'), ('and', 'CC'), ('a', 'DT'), ('younger', 'JJR'), ('sister', 'NN'), ('Tosca', 'NNP'), ('born', 'NN'), ('1974', 'CD'), ('28', 'CD'), ('29', 'CD'), ('30', 'CD'), ('31', 'CD'), ('His', 'PRP$'), ('paternal', 'JJ'), ('grandmother', 'NN'), ('was', 'VBD'), ('British', 'JJ'), ('and', 'CC'), ('he', 'PRP'), ('also', 'RB'), ('has', 'VBZ'), ('Pennsylvania', 'NNP'), ('Dutch', 'NNP'), ('ancestry', 'NN'), ('32', 'CD'), ('33', 'CD'), ('and', 'CC'), ('his', 'PRP$'), ('maternal', 'JJ'), ('grandfather', 'NN'), ('was', 'VBD'), ('American', 'JJ'), ('from', 'IN'), ('Minnesota', 'NNP'), ('34', 'CD'), ('After', 'IN'), ('his', 'PRP$'), ('parents', 'NNS'), ('divorced', 'VBN'), ('in', 'IN'), ('1980', 'CD'), ('Musk', 'NNP'), ('lived', 'VBD'), ('mostly', 'RB'), ('with', 'IN'), ('his', 'PRP$'), ('father', 'NN'), ('in', 'IN'), ('the', 'DT'), ('suburbs', 'NN'), ('of', 'IN'), ('Pretoria', 'NNP'), ('32', 'CD'), ('During', 'IN'), ('his', 'PRP$'), ('childhood', 'NN'), ('he', 'PRP'), ('had', 'VBD'), ('an', 'DT'), ('interest', 'NN'), ('in', 'IN'), ('reading', 'NN'), ('and', 'CC'), ('often', 'RB'), ('did', 'VBD'), ('so', 'RB'), ('for', 'IN'), ('hours', 'NNS'), ('at', 'IN'), ('a', 'DT'), ('time', 'NN'), ('35', 'CD'), ('At', 'IN'), ('What', 'WP'), ('age', 'NN'), ('did', 'VBD'), ('Musk', 'NNP'), ('got', 'VBD'), ('interested', 'JJ'), ('in', 'IN'), ('computing', 'VBG'), ('At', 'IN'), ('age', 'NN'), ('10', 'CD'), ('he', 'PRP'), ('developed', 'VBD'), ('an', 'DT'), ('interest', 'NN'), ('in', 'IN'), ('computing', 'VBG'), ('with', 'IN'), ('the', 'DT'), ('Commodore', 'NNP'), ('VIC', 'NNP'), ('20', 'CD'), ('36', 'CD'), ('He', 'PRP'), ('taught', 'VBD'), ('himself', 'PRP'), ('computer', 'NN'), ('programming', 'VBG'), ('at', 'IN'), ('the', 'DT'), ('age', 'NN'), ('of', 'IN'), ('12', 'CD'), ('sold', 'VBD'), ('the', 'DT'), ('code', 'NN'), ('for', 'IN'), ('a', 'DT'), ('BASIC', 'NNP'), ('based', 'VBN'), ('video', 'NN'), ('game', 'NN'), ('he', 'PRP'), ('created', 'VBD'), ('called', 'VBN'), ('Blastar', 'NNP'), ('to', 'TO'), ('a', 'DT'), ('magazine', 'NN'), ('called', 'VBN'), ('PC', 'NN'), ('and', 'CC'), ('Office', 'NNP'), ('Technology', 'NNP'), ('for', 'IN'), ('approximately', 'RB'), ('500', 'CD'), ('37', 'CD'), ('38', 'CD'), ('A', 'NNP'), ('web', 'JJ'), ('version', 'NN'), ('of', 'IN'), ('the', 'DT'), ('game', 'NN'), ('is', 'VBZ'), ('available', 'JJ'), ('online', 'JJ'), ('37', 'CD'), ('39', 'CD'), ('Musk', 'NNP'), ('was', 'VBD'), ('severely', 'RB'), ('bullied', 'VBN'), ('throughout', 'IN'), ('his', 'PRP$'), ('childhood', 'NN'), ('and', 'CC'), ('was', 'VBD'), ('once', 'RB'), ('hospitalized', 'VBN'), ('when', 'WRB'), ('a', 'DT'), ('group', 'NN'), ('of', 'IN'), ('boys', 'NNS'), ('threw', 'VBD'), ('him', 'PRP'), ('down', 'RP'), ('a', 'DT'), ('flight', 'NN'), ('of', 'IN'), ('stairs', 'NNS'), ('and', 'CC'), ('then', 'RB'), ('beat', 'VBD'), ('him', 'PRP'), ('until', 'IN'), ('he', 'PRP'), ('lost', 'VBD'), ('consciousness', 'JJ'), ('40', 'CD'), ('Musk', 'NNP'), ('was', 'VBD'), ('initially', 'RB'), ('educated', 'VBN'), ('at', 'IN'), ('private', 'JJ'), ('schools', 'NNS'), ('attending', 'VBG'), ('the', 'DT'), ('English', 'JJ'), ('speaking', 'NN'), ('Waterkloof', 'NNP'), ('House', 'NNP'), ('Pre ...

# %%
tagged[1][1]
# Out:
# 'VBD'

# %%
tags
# Out:
# ['NNP',
#  'VBD',
#  'VBN',
#  'IN',
#  'NNP',
#  'CD',
#  'CD',
#  'IN',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'CD',
#  'DT',
#  'NN',
#  'IN',
#  'NNP',
#  'NNP',
#  'MD',
#  'NNP',
#  'DT',
#  'NN',
#  'CC',
#  'JJ',
#  'IN',
#  'NNP',
#  'NNP',
#  'NNP',
#  'CD',
#  'CC',
#  'NNP',
#  'NNP',
#  'DT',
#  'JJ',
#  'JJ',
#  'JJ',
#  'NN',
#  'NN',
#  'CC',
#  'NN',
#  'PRP',
#  'VBZ',
#  'DT',
#  'JJR',
#  'NN',
#  'NNP',
#  'NN',
#  'CD',
#  'CC',
#  'DT',
#  'JJR',
#  'NN',
#  'NNP',
#  'NN',
#  'CD',
#  'CD',
#  'CD',
#  'CD',
#  'CD',
#  'PRP$',
#  'JJ',
#  'NN',
#  'VBD',
#  'JJ',
#  'CC',
#  'PRP',
#  'RB',
#  'VBZ',
#  'NNP',
#  'NNP',
#  'NN',
#  'CD',
#  'CD',
#  'CC',
#  'PRP$',
#  'JJ',
#  'NN',
#  'VBD',
#  'JJ',
#  'IN',
#  'NNP',
#  'CD',
#  'IN',
#  'PRP$',
#  'NNS',
#  'VBN',
#  'IN',
#  'CD',
#  'NNP',
#  'VBD',
#  'RB',
#  'IN',
#  'PRP$',
#  'NN',
#  'IN',
#  'DT',
#  'NN',
#  'IN',
#  'NNP',
#  'CD',
#  'IN',
#  'PRP$',
#  'NN',
#  'PRP',
#  'VBD',
#  'DT',
#  'NN',
#  'IN',
#  'NN',
#  'CC',
#  'RB',
#  'VBD',
#  'RB',
#  'IN',
#  'NNS',
#  'IN',
#  'DT',
#  'NN',
#  'CD',
#  'IN',
#  'WP',
#  'NN',
#  'VBD',
#  'NNP',
#  'VBD',
#  'JJ',
#  'IN',
#  'VBG',
#  'IN',
#  'NN',
#  'CD',
#  'PRP',
#  'VBD',
#  'DT',
#  'NN',
#  'IN',
#  'VBG',
#  'IN',
#  'DT',
#  'NNP',
#  'NNP',
#  'CD',
#  'CD',
#  'PRP',
#  'VBD',
#  'PRP',
#  'NN',
#  'VBG',
#  'IN',
#  'DT',
#  'NN',
#  'IN',
#  'CD',
#  'VBD',
#  'DT',
#  'NN',
#  'IN',
#  'DT',
#  'NNP',
#  'VBN',
#  'NN',
#  'NN',
#  'PRP',
#  'VBD',
#  'VBN',
#  'NNP',
#  'TO',
#  'DT',
#  'NN',
#  'VBN',
#  'NN',
#  'CC',
#  'NNP',
#  'NNP',
#  'IN',
#  'RB',
#  'CD',
#  'CD',
#  'CD',
#  'NNP',
#  'JJ',
#  'NN',
#  'IN',
#  'DT',
#  'NN',
#  'VBZ',
#  'JJ',
#  'NN',
#  'CD',
#  'CD',
#  'NNP',
#  'VBD',
#  'RB',
#  'VBN',
#  'IN',
#  'PRP$',
#  'NN',
#  'CC',
#  'VBD',
#  'RB',
#  'VBN',
#  'WRB',
#  'DT',
#  'NN',
#  'IN',
#  'NNS',
#  'VBD',
#  'PRP',
#  'RP',
#  'DT',
#  'NN',
#  'IN',
#  'NNS',
#  'CC',
#  'RB',
#  'VBD',
#  'PRP',
#  'IN',
#  'PRP',
#  'VBD',
#  'NN',
#  'CD',
#  'NNP',
#  'VBD',
#  'RB',
#  'VBN',
#  'IN',
#  'JJ',
#  'NNS',
#  'VBG',
#  'DT',
#  'JJ',
#  'NN',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'VBD',
#  'NNP',
#  'IN',
#  'PRP$',
#  'JJ',
#  'NNS',
#  'WRB',
#  'PRP',
#  'VBD',
#  'RB',
#  'VBN',
#  'IN',
#  'PRP$',
#  'NN',
#  'NNP',
#  'RB',
#  'VBD',
#  'IN',
#  'NNP',
#  'NNP',
#  'NNP',
#  'NNP',
#  'CC',
#  'VBD',
#  'TO',
#  'NNP',
#  'IN',
#  'NNP',
#  'CD',
#  'RB',
#  'IN',
#  'PRP$',
#  'CD',
#  'NN',
#  'CD',
#  'IN',
#  'VBG',
#  'JJ',
#  'NN',
#  'IN',
#  'PRP$',
#  'JJ',
#  'NN',
#  'NN',
#  'CD',
#  'CD',
#  'IN',
#  'IN',
#  'DT',
#  'NN',
#  'NNP',
#  'VBD',
#  'TO',
#  'VB',
#  'TO',
#  'VB',
#  'DT',
#  'JJ',
#  'NN',
#  'NNP',
#  'NNP',
#  'CD',
#  'WDT',
#  'VBD',
#  'IN',
#  'NN',
#  'IN',
#  'NNP',
#  'IN',
#  'CD',
#  'RB',
#  'VBD',
#  'PRP$',
#  'JJ',
#  'NN',
#  'JJ',
#  'TO',
#  'PRP$',
#  'NN',
#  'IN',
#  'PRP',
#  'VBD',
#  'VBN',
#  'IN',
#  'DT',
#  'JJ',
#  'NN',
#  'RB',
#  'TO',
#  'DT',
#  'JJ',
#  'NN',
#  'NN',
#  'RB',
#  'IN',
#  'DT',
#  'NN',
#  'NN',
#  'PRP',
#  'VBZ',
#  'VBN',
#  'TO',
#  'VB',
#  'RB',
#  'VBN',
#  'DT',
#  'JJ',
#  'NN',
#  'IN',
#  'NN']

# %%
from nltk import FreqDist

# %%
fdist = FreqDist(tags)

# %%
fdist.most_common()
# Out:
# [('NN', 53),
#  ('NNP', 49),
#  ('IN', 45),
#  ('CD', 33),
#  ('VBD', 26),
#  ('DT', 24),
#  ('JJ', 22),
#  ('RB', 16),
#  ('PRP', 13),
#  ('PRP$', 12),
#  ('VBN', 12),
#  ('CC', 11),
#  ('TO', 7),
#  ('NNS', 6),
#  ('VBG', 5),
#  ('VBZ', 4),
#  ('VB', 3),
#  ('WRB', 2),
#  ('JJR', 2),
#  ('WP', 1),
#  ('RP', 1),
#  ('MD', 1),
#  ('WDT', 1)]

# %%
tags = word_tokenize(sample_data)
default_tagger = nltk.DefaultTagger('NN')
default_tagger.tag(tags)
# Out:
# [('Musk', 'NN'),
#  ('was', 'NN'),
#  ('born', 'NN'),
#  ('on', 'NN'),
#  ('June', 'NN'),
#  ('28', 'NN'),
#  (',', 'NN'),
#  ('1971', 'NN'),
#  (',', 'NN'),
#  ('in', 'NN'),
#  ('Pretoria', 'NN'),
#  (',', 'NN'),
#  ('Gauteng', 'NN'),
#  (',', 'NN'),
#  ('South', 'NN'),
#  ('Africa', 'NN'),
#  (',', 'NN'),
#  ('[', 'NN'),
#  ('27', 'NN'),
#  (']', 'NN'),
#  ('the', 'NN'),
#  ('son', 'NN'),
#  ('of', 'NN'),
#  ('Maye', 'NN'),
#  ('Musk', 'NN'),
#  ('(', 'NN'),
#  ('née', 'NN'),
#  ('Haldeman', 'NN'),
#  (')', 'NN'),
#  (',', 'NN'),
#  ('a', 'NN'),
#  ('model', 'NN'),
#  ('and', 'NN'),
#  ('dietician', 'NN'),
#  ('from', 'NN'),
#  ('Regina', 'NN'),
#  (',', 'NN'),
#  ('Saskatchewan', 'NN'),
#  (',', 'NN'),
#  ('Canada', 'NN'),
#  (';', 'NN'),
#  ('[', 'NN'),
#  ('28', 'NN'),
#  (']', 'NN'),
#  ('and', 'NN'),
#  ('Errol', 'NN'),
#  ('Musk', 'NN'),
#  (',', 'NN'),
#  ('a', 'NN'),
#  ('South', 'NN'),
#  ('African', 'NN'),
#  ('electromechanical', 'NN'),
#  ('engineer', 'NN'),
#  (',', 'NN'),
#  ('pilot', 'NN'),
#  ('and', 'NN'),
#  ('sailor', 'NN'),
#  ('.', 'NN'),
#  ('He', 'NN'),
#  ('has', 'NN'),
#  ('a', 'NN'),
#  ('younger', 'NN'),
#  ('brother', 'NN'),
#  (',', 'NN'),
#  ('Kimbal', 'NN'),
#  ('(', 'NN'),
#  ('born', 'NN'),
#  ('1972', 'NN'),
#  (')', 'NN'),
#  (',', 'NN'),
#  ('and', 'NN'),
#  ('a', 'NN'),
#  ('younger', 'NN'),
#  ('sister', 'NN'),
#  (',', 'NN'),
#  ('Tosca', 'NN'),
#  ('(', 'NN'),
#  ('born', 'NN'),
#  ('1974', 'NN'),
#  (')', 'NN'),
#  ('.', 'NN'),
#  ('[', 'NN'),
#  ('28', 'NN'),
#  (']', 'NN'),
#  ('[', 'NN'),
#  ('29', 'NN'),
#  (']', 'NN'),
#  ('[', 'NN'),
#  ('30', 'NN'),
#  (']', 'NN'),
#  ('[', 'NN'),
#  ('31', 'NN'),
#  (']', 'NN'),
#  ('His', 'NN'),
#  ('paternal', 'NN'),
#  ('grandmother', 'NN'),
#  ('was', 'NN'),
#  ('British', 'NN'),
#  (',', 'NN'),
#  ('and', 'NN'),
#  ('he', 'NN'),
#  ('also', 'NN'),
#  ('has', 'NN'),
#  ('Pennsylvania', 'NN'),
#  ('Dutch', 'NN'),
#  ('ancestry', 'NN'),
#  (',', 'NN'),
#  ('[', 'NN'),
#  ('32', 'NN'),
#  (']', 'NN'),
#  ('[', 'NN'),
#  ('33', 'NN'),
#  (']', 'NN'),
#  ('and', 'NN'),
#  ('his', 'NN'),
#  ('maternal', 'NN'),
#  ('grandfather', 'NN'),
#  ('was', 'NN'),
#  ('American', 'NN'),
#  (',', 'NN'),
#  ('from', 'NN'),
#  ('Minnesota', 'NN'),
#  ('.', 'NN'),
#  ('[', 'NN'),
#  ('34', 'NN'),
#  (']', 'NN'),
#  ('After', 'NN'),
#  ('his', 'NN'),
#  ('parents', 'NN'),
#  ('divorced', 'NN'),
#  ('in', 'NN'),
#  ('1980', 'NN'),
#  (',', 'NN'),
#  ('Musk', 'NN'),
#  ('lived', 'NN'),
#  ('mostly', 'NN'),
#  ('with', 'NN'),
#  ('his', 'NN'),
#  ('father', 'NN'),
#  ('in', 'NN'),
#  ('the', 'NN'),
#  ('suburbs', 'NN'),
#  ('of', 'NN'),
#  ('Pretoria', 'NN'),
#  ('.', 'NN'),
#  ('[', 'NN'),
#  ('32', 'NN'),
#  (']', 'NN'),
#  ('During', 'NN'),
#  ('his', 'NN'),
#  ('childhood', 'NN'),
#  ('he', 'NN'),
#  ('had', 'NN'),
#  ('an', 'NN'),
#  ('interest', 'NN'),
#  ('in', 'NN'),
#  ('reading', 'NN'),
#  ('and', 'NN'),
#  ('often', 'NN'),
#  ('did', 'NN'),
#  ('so', 'NN'),
#  ('for', 'NN'),
#  ('hours', 'NN'),
#  ('at', 'NN'),
#  ('a', 'NN'),
#  ('time', 'NN'),
#  ('.', 'NN'),
#  ('[', 'NN'),
#  ('35', 'NN'),
#  (']', 'NN'),
#  ('At', 'NN'),
#  ('What', 'NN'),
#  ('age', 'NN'),
#  ('did', 'NN'),
#  ('Musk', 'NN'),
#  ('got', 'NN'),
#  ('interested', 'NN'),
#  ('in', 'NN'),
#  ('computing', 'NN'),
#  ('?', 'NN'),
#  ('At', 'NN'),
#  ('age', 'NN'),
#  ('10', 'NN'),
#  (',', 'NN'),
#  ('he', 'NN'),
#  ('developed', 'NN'),
#  ('an', 'NN'),
#  ('interest', 'NN'),
#  ('in', 'NN'),
#  ('computing', 'NN'),
#  ('with', 'NN'),
#  ('the', 'NN'),
#  ('Commodore', 'NN'),
#  ('VIC-20', 'NN'),
#  ('.', 'NN'),
#  ('[', 'NN'),
#  ('36', 'NN'),
#  (']', 'NN'),
#  ('He', 'NN'),
#  ('taught', 'NN'),
#  ('himself', 'NN'),
#  ('computer', 'NN'),
#  ('programming', 'NN'),
#  ('at', 'NN'),
#  ('the', 'NN'),
#  ('age', 'NN'),
#  ('of', 'NN'),
#  ('12', 'NN'),
#  (',', 'NN'),
#  ('sold', 'NN'),
#  ('the', 'NN'),
#  ('code', 'NN'),
#  ('for', 'NN'),
#  ('a', 'NN'),
#  ('BASIC-based', 'NN'),
#  ('video', 'NN'),
#  ('game', 'NN'),
#  ('he', 'NN'),
#  ('created', 'NN'),
#  ('called', 'NN'),
#  ('Blastar', 'NN'),
#  (',', 'NN'),
#  ('to', 'NN'),
#  ('a', 'NN'),
#  ('magazine', 'NN'),
#  ('called', 'NN'),
#  ('PC', 'NN'),
#  ('and', 'NN'),
#  ('Office', 'NN'),
#  ('Technology', 'NN'),
#  (',', 'NN'),
#  ('for', 'NN'),
#  ('approximately', 'NN'),
#  ('$', 'NN'),
#  ('500', 'NN'),
#  ('.', 'NN'),
#  ('[', 'NN'),
#  ('37', 'NN'),
#  (']', 'NN'),
#  ('[', 'NN'),
#  ('38', 'NN'),
#  (']', 'NN'),
#  ('A', 'NN'),
#  ('web', 'NN'),
#  ('version', 'NN'),
#  ('of', 'NN'),
#  ('the', 'NN'),
#  ('game', 'NN'),
#  ('is', 'NN'),
#  ('available', 'NN'),
#  ('online', 'NN'),
#  ('.', 'NN'),
#  ('[', 'NN'),
#  ('37', 'NN'),
#  (']', 'NN'),
#  ('[', 'NN'),
#  ('39', 'NN'),
#  (']', 'NN'),
#  ('Musk', 'NN'),
#  ('was', 'NN'),
#  ('severely', 'NN'),
#  ('bullied', 'NN'),
#  ('throughout', 'NN'),
#  ('his', 'NN'),
#  ('childhood', 'NN'),
#  (',', 'NN'),
#  ('and', 'NN'),
#  ('was', 'NN'),
#  ('once', 'NN'),
#  ('hospitalized', 'NN'),
#  ('when', 'NN'),
#  ('a', 'NN'),
#  ('group', 'NN'),
#  ('of', 'NN'),
#  ('boys', 'NN'),
#  ('threw', 'NN'),
#  ('him', 'NN'),
#  ('down', 'NN'),
#  ('a', 'NN'),
#  ('flight', 'NN'),
#  ('of', 'NN'),
#  ('stairs', 'NN'),
#  ('and', 'NN'),
#  ('then', 'NN'),
#  ('beat', 'NN'),
#  ('him', 'NN'),
#  ('until', 'NN'),
#  ('he', 'NN'),
#  ('lost', 'NN'),
#  ('consciousness', 'NN'),
#  ('.', 'NN'),
#  ('[', 'NN'),
#  ('40', 'NN'),
#  (']', 'NN'),
#  ('Musk', 'NN'),
#  ('was', 'NN'),
#  ('initially', 'NN'),
#  ('educated', 'NN'),
#  ('at', 'NN'),
#  ('private', 'NN'),
#  ('schools', 'NN'),
#  (',', 'NN'),
#  ('attending', 'NN'),
#  ('the', 'NN'),
#  ('English-speaking', 'NN'),
#  ('Waterkloof', 'NN'),
#  ('House', 'NN'),
#  ('Preparatory', 'NN'),
#  ('School', 'NN'),
#  ('.', 'NN'),
#  ('Mr.', 'NN'),
#  ('Singh', 'NN'),
#  ('helped', 'NN'),
#  ('Musk', 'NN'),
#  ('during', 'NN'),
#  ('his', 'NN'),
#  ('initial', 'NN'),
#  ('days', 'NN'),
#  ('when', 'NN'),
#  ('he', 'NN'),
#  ('was', 'NN'),
#  ('severely', 'NN'),
#  ('bullied', 'NN'),
#  ('during', 'NN'),
#  ('his', 'NN'),
#  ('childhood', 'NN'),
#  ('.', 'NN'),
#  ('Musk', 'NN'),
#  ('later', 'NN'),
#  ('graduated', 'NN'),
#  ('from', 'NN'),
#  ('Pretoria', 'NN'),
#  ('Boys', 'NN'),
#  ('High', 'NN'),
#  ('School', 'NN'),
#  ('and', 'NN'),
#  ('moved', 'NN'),
#  ('to', 'NN'),
#  ('Canada', 'NN'),
#  ('in', 'NN'),
#  ('June', 'NN'),
#  ('1989', 'NN'),
#  (',', 'NN'),
#  ('just', 'NN'),
#  ('before', 'NN'),
#  ('his', 'NN'),
#  ('18th', 'NN'),
#  ('birthday', 'NN'),
#  (',', 'NN'),
#  ('[', 'NN'),
#  ('41', 'NN'),
#  (']', 'NN'),
#  ('after', 'NN'),
#  ('obtaining', 'NN'),
#  ('Canadian', 'NN'),
#  ('citizenship', 'NN'),
#  ('through', 'NN'),
#  ('his', 'NN'),
#  ('Canadian-born', 'NN'),
#  ('mother', 'NN'),
#  ('.', 'NN'),
#  ('[', 'NN'),
#  ('42', 'NN'),
#  (']', 'NN'),
#  ('[', 'NN'),
#  ('43', 'NN'),
#  (']', 'NN'),
#  ('Although', 'NN'),
#  ('at', 'NN'),
#  ('the', 'NN'),
#  ('time', 'NN'),
#  ('Musk', 'NN'),
#  ('had', 'NN'),
#  ('to', 'NN'),
#  ('register', 'NN'),
#  ('to', 'NN'),
#  ('become', 'NN'),
#  ('a', 'NN'),
#  ('Canadian', 'NN'),
#  ('citizen', 'NN'),
#  (',', 'NN'),
#  ('Bill', 'NN'),
#  ('C-37', 'NN'),
#  (',', 'NN'),
#  ('which', 'NN'),
#  ('came', 'NN'),
#  ('into', 'NN'),
#  ('law', 'NN'),
#  ('in', 'NN'),
#  ('April', 'NN'),
#  ('of', 'NN'),
#  ('2009', 'NN'),
#  (',', 'NN'),
#  ('effectively', 'NN'),
#  ('made', 'NN'),
#  ('his', 'NN'),
#  ('Canadian', 'NN'),
#  ('citizenship', 'NN'),
#  ('retroactive', 'NN'),
#  ('to', 'NN'),
#  ('his', 'NN'),
#  ('birth', 'NN'),
#  ('since', 'NN'),
#  ('he', 'NN'),
#  ('was', 'NN'),
#  ('born', 'NN'),
#  ('in', 'NN'),
#  ('the', 'NN'),
#  ('first', 'NN'),
#  ('generation', 'NN'),
#  ('abroad', 'NN'),
#  ('to', 'NN'),
#  ('a', 'NN'),
#  ('Canadian-born', 'NN'),
#  ('mother', 'NN'),
#  ('.', 'NN'),
#  ('Therefore', 'NN'),
#  (',', 'NN'),
#  ('with', 'NN'),
#  ('the', 'NN'),
#  ('law', 'NN'),
#  ('change', 'NN'),
#  (',', 'NN'),
#  ('he', 'NN'),
#  ('is', 'NN'),
#  ('considered', 'NN'),
#  ('to', 'NN'),
#  ('have', 'NN'),
#  ('always', 'NN'),
#  ('been', 'NN'),
#  ('a', 'NN'),
#  ('Canadian', 'NN'),
#  ('citizen', 'NN'),
#  ('by', 'NN'),
#  ('birth', 'NN'),
#  ('.', 'NN')]

# %% [markdown]
# ## Custom Tagging

# %%
def pos(text):
    for word in text:
        for letter in arange(0, len(word)):

# %% [markdown]
# Part - 2
#
# Create your own Tagger using the following rules
#
# Let's try to understand some Parts Of Speech
#
#     Possesion Noun (NN$) - any word which ends with 's
#
#         Jennifer’s new handbag matches her shoes perfectly
#
#     Gerund (VBG) - any word which ends with ing
#
#         Swimming in the ocean has been Sharon’s passion since she was five years old.
#
#     Simple Past (VBD) - any word which ends with ed
#
#         We crossed the Channel yesterday.
#
#     Modal (MD) - any word which ends with ould
#
#         He should not be late
#
#     Third Singular Present (VBZ) - any word which ends with es
#
#         He misses her so much
#
#     Numbers (CD) - any number integer or decimal
#
#         24.90
#
#     Plural Nouns (NNS) - any word ending with s
#
#         You stole my ideas and didn’t give me any credit.

# %%
traindata = [ [ ('Swimming', 'VBG'), ('crossed', 'VBD'), ('charged', 'VBD'), 
                ('should', 'MD'), ('could', 'MD'), ('.', '.') ,('misses', 'VBZ'),('24', 'CD'),('ideas', 'NNS'),('Jennifer’s', 'NN$')],
              [ ('Kissing', 'VBG'), ('tracked', 'VBD'), ('pissed', 'VBD'), 
                ('mould', 'MD'), ('would', 'MD'), ('.', '.') ,('kisses', 'VBZ'),('34', 'CD'),('roses', 'NNS'),('Robin’s', 'NN$') ] ]

# %%
patterns = [
    (r'\b\w+\'s\b', 'NN$'),  # Possesion Noun 
    (r'\b\w+ing\b', 'VBG'),  # Gerund 
    (r'\b\w+ed\b', 'VBD'),  # Simple Past 
    (r'\b\w+ould\b', 'MD'), # Modal 
    (r'\b\w+es\b', 'VBZ'), # Third Singular Present 
    (r'\b\d+\b', 'CD'), # Numbers
    (r'\b\w+s\b', 'NNS') # Plural Nouns 
]

# %%
regex_tagger = nltk.RegexpTagger(pattern)

# %%
sentences = sent_tokenize(sample_data)

# %%
for line in sentences:
    word = word_tokenize(line)
    print(regex_tagger.tag(word))
# Out:
# [('Musk', None), ('was', None), ('born', None), ('on', None), ('June', None), ('28', 'CD'), (',', None), ('1971', 'CD'), (',', None), ('in', None), ('Pretoria', None), (',', None), ('Gauteng', None), (',', None), ('South', None), ('Africa', None), (',', None), ('[', None), ('27', 'CD'), (']', None), ('the', None), ('son', None), ('of', None), ('Maye', None), ('Musk', None), ('(', None), ('née', None), ('Haldeman', None), (')', None), (',', None), ('a', None), ('model', None), ('and', None), ('dietician', None), ('from', None), ('Regina', None), (',', None), ('Saskatchewan', None), (',', None), ('Canada', None), (';', None), ('[', None), ('28', 'CD'), (']', None), ('and', None), ('Errol', None), ('Musk', None), (',', None), ('a', None), ('South', None), ('African', None), ('electromechanical', None), ('engineer', None), (',', None), ('pilot', None), ('and', None), ('sailor', None), ('.', None)]
# [('He', None), ('has', None), ('a', None), ('younger', None), ('brother', None), (',', None), ('Kimbal', None), ('(', None), ('born', None), ('1972', 'CD'), (')', None), (',', None), ('and', None), ('a', None), ('younger', None), ('sister', None), (',', None), ('Tosca', None), ('(', None), ('born', None), ('1974', 'CD'), (')', None), ('.', None)]
# [('[', None), ('28', 'CD'), (']', None), ('[', None), ('29', 'CD'), (']', None), ('[', None), ('30', 'CD'), (']', None), ('[', None), ('31', 'CD'), (']', None), ('His', None), ('paternal', None), ('grandmother', None), ('was', None), ('British', None), (',', None), ('and', None), ('he', None), ('also', None), ('has', None), ('Pennsylvania', None), ('Dutch', None), ('ancestry', None), (',', None), ('[', None), ('32', 'CD'), (']', None), ('[', None), ('33', 'CD'), (']', None), ('and', None), ('his', None), ('maternal', None), ('grandfather', None), ('was', None), ('American', None), (',', None), ('from', None), ('Minnesota', None), ('.', None)]
# [('[', None), ('34', 'CD'), (']', None), ('After', None), ('his', None), ('parents', None), ('divorced', 'VBD'), ('in', None), ('1980', 'CD'), (',', None), ('Musk', None), ('lived', 'VBD'), ('mostly', None), ('with', None), ('his', None), ('father', None), ('in', None), ('the', None), ('suburbs', None), ('of', None), ('Pretoria', None), ('.', None)]
# [('[', None), ('32', 'CD'), (']', None), ('During', 'VBG'), ('his', None), ('childhood', None), ('he', None), ('had', None), ('an', None), ('interest', None), ('in', None), ('reading', 'VBG'), ('and', None), ('often', None), ('did', None), ('so', None), ('for', None), ('hours', None), ('at', None), ('a', None), ('time', None), ('.', None)]
# [('[', None), ('35', 'CD'), (']', None), ('At', None), ('What', None), ('age', None), ('did', None), ('Musk', None), ('got', None), ('interested', 'VBD'), ('in', None), ('computing', 'VBG'), ('?', None)]
# [('At', None), ('age', None), ('10', 'CD'), (',', None), ('he', None), ('developed', 'VBD'), ('an', None), ('interest', None), ('in', None), ('computing', 'VBG'), ('with', None), ('the', None), ('Commodore', None), ('VIC-20', None), ('.', None)]
# [('[', None), ('36', 'CD'), (']', None), ('He', None), ('taught', None), ('himself', None), ('computer', None), ('programming', 'VBG'), ('at', None), ('the', None), ('age', None), ('of', None), ('12', 'CD'), (',', None), ('sold', None), ('the', None), ('code', None), ('for', None), ('a', None), ('BASIC-based', None), ('video', None), ('game', None), ('he', None), ('created', 'VBD'), ('called', 'VBD'), ('Blastar', None), (',', None), ('to', None), ('a', None), ('magazine', None), ('called', 'VBD'), ('PC', None), ('and', None), ('Office', None), ('Technology', None), (',', None), ('for', None), ('approximately', None), ('$', None), ('500', 'CD'), ('.', None)]
# [('[', None), ('37', 'CD'), (']', None), ('[', None), ('38', 'CD'), (']', None), ('A', None), ('web', None), ('version', None), ('of', None), ('the', None), ('game', None), ('is', None), ('available', None), ('online', None), ('.', None)]
# [('[', None), ('37', 'CD'), (']', None), ('[', None), ('39', 'CD'), (']', None), ('Musk', None), ('was', None), ('severely', None), ('bullied', 'VBD'), ('throughout', None), ('his', None), ('childhood', None), (',', None), ('and', None), ('was', None), ('once', None), ('hospitalized', 'VBD'), ('when', None), ('a', None), ('group', None), ('of', None), ('boys', None), ('threw', None), ('him', None), ('down', None), ('a', None), ('flight', None), ('of', None), ('stairs', None), ('and', None), ('then', None), ('beat', None), ('him', None), ('until', None), ('he', None), ('lost', None), ('consciousness', None), ('.', None)]
# [('[', None), ('40', 'CD'), (']', None), ('Musk', None), ('was', None), ('initially', None), ('educated', 'VBD'), ('at', None), ('private', None), ('schools', None), (',', None), ('attending', 'VBG'), ('the', None), ('English-speaking', None), ('Waterkloof', None), ('House', None), ('Preparatory', None), ('School', None), ('.', None)]
# [('Mr.', None), ('Singh', None), ('helped', 'VBD'), ('Musk', None), ('during', 'VBG'), ('his', None), ('initial', None), ('days', None), ('when', None), ('he', None), ('was', None), ('severely', None), ('bullied', 'VBD'), ('during', 'VBG'), ('his', None), ('childhood', None), ('.', None)]
# [('Musk', None), ('later', None), ('graduated', 'VBD'), ('from', None), ('Pretoria', None), ('Boys', None), ('High', None), ('School', None), ('and', None), ('moved', 'VBD'), ('to', None), ('Canada', None), ('in', None), ('June', None), ('1989', 'CD'), (',', None), ('just', None), ('before', None), ('his', None), ('18th', None), ('birthday', None), (',', None), ('[', None), ('41', 'CD'), (']', None), ('after', None), ('obtaining', 'VBG'), ('Canadian', None), ('citizenship', None), ('through', None), ('his', None), ('Canadian-born', None), ('mother', None), ('.', None)]
# [('[', None), ('42', 'CD'), (']', None), ('[', None), ('43', 'CD'), (']', None), ('Although', None), ('at', None), ('the', None), ('time', None), ('Musk', None), ('had', None), ('to', None), ('register', None), ('to', None), ('become', None), ('a', None), ('Canadian', None), ('citizen', None), (',', None), ('Bill', None), ('C-37', None), (',', None), ('which', None), ('came', None), ('into', None), ('law', None), ('in', None), ('April', None), ('of', None), ('2009', 'CD'), (',', None), ('effectively', None), ('made', None), ('his', None), ('Canadian', None), ('citizenship', None), ('retroactive', None), ('to', None), ('his', None), ('birth', None), ('since', None), ('he', None), ('was', None), ('born', None), ('in', None), ('the', None), ('first', None), ('generation', None), ('abroad', None), ('to', None), ('a', None), ('Canadian-born', None), ('mother', None), ('.', None)]
# [('Therefore', None), (',', None), ('with', None), ('the', None), ('law', None), ('change', None), (',', None), ('he', None), ('is', None), ('considered', 'VBD'), ('to', None), ('have', None), ('always', None), ('been', None), ('a', None), ('Canadian', None), ('citizen', None), ('by', None), ('birth', None), ('.', None)]
